# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn import svm
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import RandomizedSearchCV
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.pipeline import Pipeline
from sklearn.ensemble import AdaBoostRegressor, VotingRegressor
from sklearn.datasets import make_regression
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv("test.csv")
train_data.head()
test_data.head()
# Out:
#    listing_id                               title    make   model  \
# 0     1303772                  Honda Vezel 1.5A X   honda   vezel
# 1     1323166  Mazda 3 1.6A SP (COE till 10/2027)   mazda       3
# 2     1308405       MINI Cooper S Countryman 2.0A    mini  cooper
# 3     1216706                  Toyota Vios 1.5A G  toyota    vios
# 4     1298206                     Mazda 3 HB 1.5A   mazda       3
#
#                                          description  manufactured  \
# 0                                               4614        2015.0
# 1  extremely well maintained and in pristine cond...        2007.0
# 2  1 owner! beautiful island blue color! eurokars...        2019.0
# 3  fully agent maintain! genuine low mileage at 5...        2019.0
# 4  workshop check/sta evaluation available. accid...        2015.0
#
#   original_reg_date     reg_date  type_of_vehicle  \
# 0               NaN  29-apr-2015              suv
# 1               NaN  26-oct-2007  mid-sized sedan
# ...

# %%
train_data.drop(['listing_id'],axis=1,inplace=True)
test_data.drop(['listing_id'],axis=1,inplace=True)

# %%
print(train_data['price'].describe())
plt.figure(figsize=(15, 15))
sns.distplot(train_data['price'], color='g', bins=1000, hist_kws={'alpha': 0.4});
# Out:
# count    2.500000e+04
# mean     1.151486e+05
# std      1.555725e+05
# min      7.000000e+02
# 25%      4.914100e+04
# 50%      7.888800e+04
# 75%      1.258000e+05
# max      2.899999e+06
# Name: price, dtype: float64
# C:\Users\echo\AppData\Local\Temp\ipykernel_14632\3173429211.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_data['price'], color='g', bins=1000, hist_kws={'alpha': 0.4});

# %%
list(set(train_data.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('float64'), dtype('int64')]

# %%
train_numerical = train_data.select_dtypes(include = ['float64', 'int64'])
train_numerical.head()
# Out:
#    manufactured  curb_weight  power  engine_cap  no_of_owners  depreciation  \
# 0        2018.0       1884.0  280.0      2995.0           2.0       34270.0
# 1        2017.0       1465.0  135.0      1991.0           2.0       21170.0
# 2        2007.0       1648.0  118.0      2354.0           3.0       12520.0
# 3        2008.0       1195.0   80.0      1598.0           3.0       10140.0
# 4        2006.0       1660.0  183.0      2995.0           6.0       13690.0
#
#      coe  road_tax  dereg_value   mileage      omv       arf  \
# 0  48011    2380.0     103323.0   96000.0  88906.0  132031.0
# 1  47002    1202.0      45179.0   85680.0  40678.0   43950.0
# 2  50355    2442.0      16003.0  138000.0  27994.0   30794.0
# 3  27571    1113.0      12184.0  160000.0  16084.0   16084.0
# 4  48479    3570.0       9138.0  183000.0  50414.0   55456.0
#
#    indicative_price     price
# 0               NaN  193788.0
# 1               NaN   96800.0
# 2               NaN   39800.0
# ...

# %%
f = pd.melt(train_numerical, value_vars = train_numerical.columns)
g = sns.FacetGrid(f, col="variable",  col_wrap=4, sharex=False, sharey=False)
g.map(lambda _x, **kwargs: sns.histplot(_x, kde=True, stat="density", bins=30,  **kwargs), 'value')
# Out:
# E:\anaconda\envs\CS5228\lib\site-packages\numpy\lib\_histograms_impl.py:895: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %%
train_categorical=train_data.select_dtypes(include='object')
train_categorical.head()
# Out:
#                                                title           make    model  \
# 0  Land Rover Range Rover Velar 3.0A Si6 R-Dynami...     land rover    range
# 1   Mercedes-Benz C-Class C200 Sport Premium Sunroof  mercedes-benz     c200
# 2              Honda Odyssey 2.4A (COE till 09/2027)          honda  odyssey
# 3       Toyota Corolla Altis 1.6A (COE till 12/2028)         toyota    altis
# 4                     Lexus GS300 (COE till 06/2026)          lexus       gs
#
#                                          description original_reg_date  \
# 0  1 owner, no repairs needed! it looks great, in...               NaN
# 1  rare beautiful white c200 sport premium sunroo...               NaN
# 2            comes with warranty. full service done.               NaN
# 3                                                  0               NaN
# 4  wear and tear done up. well maintained and reg...               NaN
#
# ...

# %%
all_data=pd.concat([train_data,test_data])
nan_data = (all_data.isnull().sum())*100/all_data.shape[0]
nan_data= nan_data.drop(nan_data[nan_data== 0].index).sort_values(ascending=False)
nan_data
miss_data = pd.DataFrame({'Missing Ratio' :nan_data})
miss_data
# Out:
#                    Missing Ratio
# indicative_price      100.000000
# opc_scheme             99.402857
# original_reg_date      98.994286
# lifespan               90.562857
# fuel_type              76.488571
# price                  28.571429
# mileage                21.342857
# accessories            15.368571
# power                  10.645714
# road_tax               10.611429
# make                    5.305714
# features                3.331429
# description             2.708571
# engine_cap              2.374286
# depreciation            2.022857
# curb_weight             1.191429
# dereg_value             0.865714
# arf                     0.682857
# omv                     0.265714
# no_of_owners            0.074286
# manufactured            0.028571

# %%
all_data.drop(['indicative_price','opc_scheme','original_reg_date','lifespan','fuel_type'],axis=1,inplace=True)
test_data.drop(['indicative_price','opc_scheme','original_reg_date','lifespan','fuel_type'],axis=1,inplace=True)
train_data.drop(['indicative_price','opc_scheme','original_reg_date','lifespan','fuel_type'],axis=1,inplace=True)

# %%
plt.scatter(x=train_data['mileage']/1e6,y=train_data['price']/1e6,marker='.',s=2)
print(train_data['mileage'].describe())
# Out:
# count    2.500000e+04
# mean     8.596355e+04
# std      4.582250e+04
# min      1.000000e+00
# 25%      6.075825e+04
# 50%      8.608762e+04
# 75%      1.060000e+05
# max      1.290000e+06
# Name: mileage, dtype: float64

# %%
train_data['mileage'].fillna(np.mean(all_data['mileage']),inplace=True)
test_data['mileage'].fillna(np.mean(all_data['mileage']),inplace=True)
# Out:
# C:\Users\echo\AppData\Local\Temp\ipykernel_14632\1927529796.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['mileage'].fillna(np.mean(all_data['mileage']),inplace=True)
# C:\Users\echo\AppData\Local\Temp\ipykernel_14632\1927529796.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
train_data['accessories'].fillna(None,inplace=True)
test_data['accessories'].fillna(None,inplace=True)

train_data['power'].fillna(0,inplace=True)
test_data['power'].fillna(0,inplace=True)

train_data['road_tax'].fillna(None,inplace=True)
test_data['road_tax'].fillna(None,inplace=True)

train_data['make'].fillna(None,inplace=True)
test_data['make'].fillna(None,inplace=True)

train_data['features'].fillna(None,inplace=True)
test_data['features'].fillna(None,inplace=True)

train_data['description'].fillna(None,inplace=True)
test_data['description'].fillna(None,inplace=True)

train_data['engine_cap'].fillna(None,inplace=True)
test_data['engine_cap'].fillna(None,inplace=True)

train_data['depreciation'].fillna(None,inplace=True)
test_data['depreciation'].fillna(None,inplace=True)

train_data['curb_weight'].fillna(None,inplace=True)
test_data['curb_weight'].fillna(None,inplace=True)

train_data['dereg_value'].fillna(None,inplace=True)
test_data['dereg_value'].fillna(None,inplace=True)

train_data['arf'].fillna(None,inplace=True)
test_data['arf'].fillna(None,inplace=True)

train_data['omv'].fillna(None,inplace=True)
test_data['omv'].fillna(None,inplace=True)

train_data['no_of_owners'].fillna(None,inplace=True)
test_data['no_of_owners'].fillna(None,inplace=True)

train_data['manufactured'].fillna(None,inplace=True)
test_data['manufactured'].fillna(None,inplace=True)
